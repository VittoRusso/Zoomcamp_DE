# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df_iter = pd.read_csv("yellow_tripdata_2021-01.csv.gz", iterator=True, chunksize=100000)

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52                3
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45                2
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22                2
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37                2
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44                5
#
# ...

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 1000

# %%
for chunk in df_iter:
    chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# /tmp/ipykernel_14673/2341132965.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in df_iter:

# %%
## Import Zones into database manually

# %%
df_zones = pd.read_csv("taxi_zone_lookup.csv")

# %%
df_zones
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
print(pd.io.sql.get_schema(df_zones, 'taxi_zones'))
# Out:
# CREATE TABLE "taxi_zones" (
# "LocationID" INTEGER,
#   "Borough" TEXT,
#   "Zone" TEXT,
#   "service_zone" TEXT
# )

# %%
df_zones.to_sql(name='taxi_zones', con=engine, if_exists='replace')
# Out:
# 265

# %%
## Import Green Taxis into database manually

# %%
df_green_taxis = pd.read_csv("green_tripdata_2019-01.csv.gz")

# %%
df_green_taxis
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1              2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2              2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3              2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4              2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ...          ...                  ...                   ...
# 630913         2  2019-01-31 23:08:27   2019-01-31 23:22:59
# 630914         2  2019-01-31 23:21:26   2019-01-31 23:23:05
# 630915         2  2019-01-31 23:30:05   2019-01-31 23:36:14
# 630916         2  2019-01-31 23:59:58   2019-02-01 00:04:18
# 630917         2  2019-01-31 23:18:22   2019-01-31 23:26:06
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                       N           1           264           264
# 1                       N           1            97            49
# ...

# %%
print(pd.io.sql.get_schema(df_green_taxis, 'green_taxi_data'))
# Out:
# CREATE TABLE "green_taxi_data" (
# "VendorID" INTEGER,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" INTEGER,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" INTEGER,
#   "trip_type" INTEGER,
#   "congestion_surcharge" REAL
# )

# %%
df_green_taxis.lpep_pickup_datetime = pd.to_datetime(df_green_taxis.lpep_pickup_datetime)
df_green_taxis.lpep_dropoff_datetime = pd.to_datetime(df_green_taxis.lpep_dropoff_datetime)

# %%
df_green_taxis.head(n=0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
df_green_taxis.to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 918
